# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
climate_change=pd.read_csv("Global_Tempraturechange_1960_2020.csv")
climate_change
# Out:
#        Domain Code              Domain  Area Code (FAO)         Area  \
# 0               ET  Temperature change                2  Afghanistan
# 1               ET  Temperature change                2  Afghanistan
# 2               ET  Temperature change                2  Afghanistan
# 3               ET  Temperature change                2  Afghanistan
# 4               ET  Temperature change                2  Afghanistan
# ...            ...                 ...              ...          ...
# 229920          ET  Temperature change              181     Zimbabwe
# 229921          ET  Temperature change              181     Zimbabwe
# 229922          ET  Temperature change              181     Zimbabwe
# 229923          ET  Temperature change              181     Zimbabwe
# 229924          ET  Temperature change              181     Zimbabwe
#
#         Element Code             Element  Months Code               Months  \
# ...

# %%
#draw line plot
sns.lineplot(x="Year",y="Value", hue="Element", data=climate_change)
plt.title("Global_Climate_Change")
sns.set_style("dark")
plt.show()

# %%
#draw line plot
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
plt.Figure(figsize=(5,5))
climate_change=pd.read_csv("Global_Tempraturechange_1960_2020.csv")
sns.barplot(x="Year",y="Value", hue="Element", saturation=0.5, data=climate_change)
plt.title("Global_Climate_Change")
sns.set_style("dark")
plt.show()

# %%
import pandas as pd
climate_change=pd.read_csv("Global_Tempraturechange_1960_2020.csv")
climate_change.head()
# Out:
#   Domain Code              Domain  Area Code (FAO)         Area  Element Code  \
# 0          ET  Temperature change                2  Afghanistan          7271
# 1          ET  Temperature change                2  Afghanistan          7271
# 2          ET  Temperature change                2  Afghanistan          7271
# 3          ET  Temperature change                2  Afghanistan          7271
# 4          ET  Temperature change                2  Afghanistan          7271
#
#               Element  Months Code   Months  Year Code  Year Unit  Value Flag  \
# 0  Temperature change         7001  January       1961  1961   ?C  0.746   Fc
# 1  Temperature change         7001  January       1962  1962   ?C  0.009   Fc
# 2  Temperature change         7001  January       1963  1963   ?C  2.695   Fc
# 3  Temperature change         7001  January       1964  1964   ?C -5.277   Fc
# 4  Temperature change         7001  January       1965  1965   ?C  1.827   Fc
#
#   Flag Description
# ...

# %%
import pandas as pd
climate_change=pd.read_csv("Global_Tempraturechange_1960_2020.csv")
climate_change.head()
sns.lineplot(climate_change['Year'],climate_change['Value'])
plt.ylabel("Mean")
plt.title("Average Global Mean Temperature")
# Out:
# C:\Users\MULTI.LAPTOP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Average Global Mean Temperature')

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
climate_change=pd.read_csv("20years_data.csv")
climate_change
# Out:
#       Domain Code              Domain  Area Code (FAO)         Area  \
# 0              ET  Temperature change                2  Afghanistan
# 1              ET  Temperature change                2  Afghanistan
# 2              ET  Temperature change                2  Afghanistan
# 3              ET  Temperature change                2  Afghanistan
# 4              ET  Temperature change                2  Afghanistan
# ...           ...                 ...              ...          ...
# 85046          ET  Temperature change              181     Zimbabwe
# 85047          ET  Temperature change              181     Zimbabwe
# 85048          ET  Temperature change              181     Zimbabwe
# 85049          ET  Temperature change              181     Zimbabwe
# 85050          ET  Temperature change              181     Zimbabwe
#
#        Element Code             Element  Months Code               Months  \
# 0              7271  Temperature change         7001              January
# ...

# %%
plt.Figure(figsize=(10,10))
sns.barplot(x="Year",y="Value", hue="Element", saturation=0.5, data=climate_change)
plt.title("Global climate change")
sns.set_style("dark")
plt.show()

# %%
climate_change=pd.read_csv("05years_data.csv")
climate_change
# Out:
#       Domain Code              Domain  Area Code (FAO)         Area  \
# 0              ET  Temperature change                2  Afghanistan
# 1              ET  Temperature change                2  Afghanistan
# 2              ET  Temperature change                2  Afghanistan
# 3              ET  Temperature change                2  Afghanistan
# 4              ET  Temperature change                2  Afghanistan
# ...           ...                 ...              ...          ...
# 49703          ET  Temperature change              181     Zimbabwe
# 49704          ET  Temperature change              181     Zimbabwe
# 49705          ET  Temperature change              181     Zimbabwe
# 49706          ET  Temperature change              181     Zimbabwe
# 49707          ET  Temperature change              181     Zimbabwe
#
#        Element Code             Element  Months Code               Months  \
# 0              7271  Temperature change         7001              January
# ...

# %%
plt.Figure(figsize=(10,10))
sns.barplot(x="Year",y="Value", hue="Element",saturation=0.5, data=climate_change )
plt.title("Global climate change")
sns.set_style("dark")
plt.show()

# %%
plt.Figure(figsize=(10,10))
sns.barplot(x="Year",y="Value", hue="Element", data=climate_change)
plt.title("Global climate change")
sns.set_style("dark")
plt.show()
