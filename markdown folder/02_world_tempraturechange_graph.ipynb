# %%
# import library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# load data set
climate_change= pd.read_csv("Global_Tempraturechange.csv")
climate_change
# Out:
#       Domain Code              Domain  Area Code (FAO)         Area  \
# 0              ET  Temperature change                2  Afghanistan
# 1              ET  Temperature change                2  Afghanistan
# 2              ET  Temperature change                2  Afghanistan
# 3              ET  Temperature change                2  Afghanistan
# 4              ET  Temperature change                2  Afghanistan
# ...           ...                 ...              ...          ...
# 26685          ET  Temperature change              181     Zimbabwe
# 26686          ET  Temperature change              181     Zimbabwe
# 26687          ET  Temperature change              181     Zimbabwe
# 26688          ET  Temperature change              181     Zimbabwe
# 26689          ET  Temperature change              181     Zimbabwe
#
#        Element Code             Element  Months Code               Months  \
# 0              7271  Temperature change         7001              January
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
climate_change= pd.read_csv("Global_Tempraturechange.csv")

sns.lineplot(x="Year",y="Value", data=climate_change)
plt.title(" Global Climate Chage")
sns.set_style("dark")
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
climate_change= pd.read_csv("Global_Tempraturechange.csv")
plt.Figure(figsize=(8,6))
sns.barplot(x="Year",y="Value", hue="Element", data=climate_change)
plt.title("Global climate change")
sns.set_style("dark")
plt.show()
