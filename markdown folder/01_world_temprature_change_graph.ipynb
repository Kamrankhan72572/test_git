# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

temp_change=pd.read_csv("Global_Tempraturechange_2020.csv")
temp_change
# Out:
#     Domain Code              Domain  Area Code (FAO)  \
# 0            ET  Temperature change                2
# 1            ET  Temperature change                3
# 2            ET  Temperature change                4
# 3            ET  Temperature change                5
# 4            ET  Temperature change                6
# ..          ...                 ...              ...
# 233          ET  Temperature change              243
# 234          ET  Temperature change              205
# 235          ET  Temperature change              249
# 236          ET  Temperature change              251
# 237          ET  Temperature change              181
#
#                           Area  Element Code             Element  Months Code  \
# 0                  Afghanistan          7271  Temperature change         7001
# 1                      Albania          7271  Temperature change         7001
# 2                      Algeria          7271  Temperature change         7001
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

temp_change=pd.read_csv("Global_Tempraturechange_2020.csv")
temp_change
sns.lineplot(x="Area",y="Value",hue="Element", data=temp_change)
plt.title("Global_climate_change")
sns.set_style("dark")
plt.show()
